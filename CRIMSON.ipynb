# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #                                                          CRIMSON

# %%
#---Imports

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from itertools import product
plt.style.use("seaborn-v0_8")
df = pd.read_csv("DataForInstruments/forex_pairs.csv", parse_dates = ["Date"], index_col = "Date")
df
# Out:
#             AUDEUR=X  EURUSD=X  USDGBP=X
# Date
# 2004-01-01   0.59780  1.258194   0.56016
# 2004-01-02   0.60314  1.258194   0.55751
# 2004-01-05   0.60467  1.268698   0.55334
# 2004-01-06   0.60350  1.272103   0.54906
# 2004-01-07   0.60728  1.264095   0.55012
# ...              ...       ...       ...
# 2020-06-24   0.61349  1.131235   0.79841
# 2020-06-25   0.60938  1.125087   0.80561
# 2020-06-26   0.61373  1.122208   0.80480
# 2020-06-29   0.61128  1.122586   0.81023
# 2020-06-30   0.61097  1.124720   0.81231
#
# [4295 rows x 3 columns]

# %%
#---Strategies Included

suportedStrategies = ["SMA CROSSOVER", "CONTRARIAN/MOMENTUM"]

# %%
#---MAINMENU INITIATION

print("Hello ADAM")
print("What canelp you with?")

print("(1)Backtesting?")
print("(2)LiveTrading? ")
print("(3)Should I fuck off??")

optanswer = input()

if optanswer == "1":
    print("Which strategy would you like to test?")
    cnum = 0
    for strategy in supportedStrategies:
        cnum += 1
        print(f"{cnum}. {strategy}")
elif optanswer== "2":
    print("To be Made")
# Out:
# Hello ADAM
# What I can help you with?
# (1)Backtesting?
# (2)LiveTrading?
# (3)Should I fuck off??
# 1
# Which strategy you want to backtest?
# 1. SMA CROSSOVER
# 2. CONTRARIAN/MOMENTUM
